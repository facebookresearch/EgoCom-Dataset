# %% [markdown]
# # This file uses Google Speech to Text to transcribe all of the EGOCOM audio (as well as ICA source estimates).
#
# ## This script uses smart GET/FETCH HTTP protocols to asynchronously transcribe many audio files in parallel. It repeatedly queries Google's servers, always pushing the max limit of parallel requests it can take, and waits automatically when needed.

# %%
from __future__ import print_function, absolute_import, division, unicode_literals, with_statement # Python 2 compatibility

import io
import os

from datetime import timedelta, datetime
import subprocess
import json
import time
import os
import pickle

# %%
def async_srt_format_timestamp(seconds):
    seconds = float(seconds)
    stamp = str(timedelta(seconds=seconds))
    first, second, third = stamp.split(":")
    third = "{:.3f}".format(float(third))
    sec, milisec = third.split(".")
    third = ",".join([sec.zfill(2), milisec])
    return ":".join([first.zfill(2), second.zfill(2), third])

def write_subtitles(lrrr, wfn = None):
    '''
    Parameters
    ----------
    lrr is a google.cloud.speech_v1.types.LongRunningRecognizeResponse
    Requires enable_word_time_offsets = True (see example below)
    
    Example for where lrrr comes from
    ---------------------------------
    
    audio = types.RecognitionAudio(uri=gcs_uri)
    config = types.RecognitionConfig(
        sample_rate_hertz=44100,
        language_code='en-US',
        enable_word_time_offsets=True)

    operation = client.long_running_recognize(config, audio)
    lrrr = operation.result(timeout=90)
    '''
    
    max_words_per_subtitle = 16
    if wfn is not None:
        with open(wfn, 'w') as f:
            f.write('')
        wf = open(wfn, 'a')
    else:
        wf = None

    cnt = 0
    for r in lrrr["results"]:
        word_dicts = r["alternatives"][0]["words"]
        for i in range(0, len(word_dicts), max_words_per_subtitle):
            cnt += 1
            words_range = word_dicts[i:i+max_words_per_subtitle]
            words = [word_info["word"] for word_info in words_range]
            words = " ".join(words[:len(words) // 2]) +  "\n" + " ".join(words[len(words) // 2:])
            start_time = words_range[0]["startTime"][:-1]
            end_time = words_range[-1]["endTime"][:-1]
            print(cnt, file=wf)
            print(async_srt_format_timestamp(start_time), "-->", async_srt_format_timestamp(end_time), file=wf)
            print(words, file=wf)
            print(file=wf)

# %%
pickle_loc =  "/home/cgn/Downloads/egocom-pickles/"
# subtitle_loc = "/home/cgn/Downloads/egocom-aligned-final/"
json_loc = "/home/cgn/Downloads/egocom-intermediate/"
# gcs_uri_loc = "gs://egocom-audio/wav16-summed/"
# keys = sorted([fn[:-4] for fn in os.listdir("/home/cgn/Downloads/egocom-audio-only-summed/")])
# gcs_uri_loc = "gs://egocom-audio/wav16-all/"
# keys = sorted([fn[:-4] for fn in os.listdir("/home/cgn/Downloads/egocom-audio-only/")])
gcs_uri_loc = "gs://egocom-audio/wav16-ica/"
keys = sorted([fn[:-4] for fn in os.listdir("/home/cgn/Downloads/egocom-ICA/")])

# %%
# POST service requestS for transcription (via PROTOCOL)
# See: https://cloud.google.com/speech-to-text/docs/async-recognize#speech-async-recognize-gcs-protocol

process_ids = []
for key in keys:
    json_fn = json_loc +key + ".json"
    json_string = '''{{
      "config": {{
          "sampleRateHertz": 44100,
          "languageCode": "en-US",
          "enableWordTimeOffsets": true,
      }},
      "audio": {{
          "uri":"{gcs_uri}"
      }}
    }}'''.format(gcs_uri = gcs_uri_loc + key + ".wav")
    print(json_string, file=open(json_fn, 'w'))

    cmd = """curl -s -H "Content-Type: application/json" \
        -H "Authorization: Bearer "$(gcloud auth application-default print-access-token) \
        https://speech.googleapis.com/v1/speech:longrunningrecognize \
        -d @{json_fn}""".format(json_fn = json_fn)
    
    done = False
    while not done:
        out = json.loads(subprocess.check_output(cmd, shell = True))
        if 'name' in out:
            process_ids.append(out["name"])
            done = True
        elif 'error' in out and out['error']['code'] == 429:
            # Google Speech API limits the amount of requests per 100 seconds.
            print('Sleeping 50 seconds. Started sleeping at', datetime.now())
            time.sleep(50)
        else:
            raise Exception("ERROR parsing {f}:\n".format(f=json_fn)+str(out))
        
    os.remove(json_fn)

# GET service requests (via PROTOCOL)

print("POST requests completed. Now we fetch results via GET requests (once Google Speech API completes).\n")
for name, key in zip(process_ids, keys):
    print('Fetching. Job name:', name, "Key:", key)
    done = False
    get_request_cnt = 0
    while not done:
        get_request_cnt += 1
        # If multiple tries, wait 30s for results to finish computing.
        if get_request_cnt > 1:
            time.sleep(30)
        cmd = '''curl -H "Authorization: Bearer "$(gcloud auth application-default print-access-token) \
             -H "Content-Type: application/json; charset=utf-8" \
             "https://speech.googleapis.com/v1/operations/{name}"'''.format(name=name)
        out = json.loads(subprocess.check_output(cmd, shell = True))
        if 'error' in out.keys():
            raise Exception("ERROR during longrunningrecognize():\n"+str(out))
        elif 'progressPercent' in out['metadata'].keys():
            pp = out['metadata']["progressPercent"]
            if pp < 100:
                print('Still transcribing... Percent done:', pp)
            else:
                print('Success. Transcription received.')
                done = True
        else:
            print('Job', name, 'is still waiting to be processed.')
            
    # Pickle all transcription data for re-use later.
    data = [z['alternatives'][0] for z in out["response"]["results"]]
#     confidences = [z["confidence"] for z in data]
#     transcripts = [z["transcript"] for z in data]
#     starts = [d['words'][0]['startTime'] for d in data]
#     ends = [d['words'][-1]['endTime'] for d in data]
#     # Create dictionary of lists
#     DL = {
#         'confidence': confidences,
#         'transcript': transcripts,
#         'startTime': starts,
#         'endTime': ends,
#     }
#     # Convert to list of dictionaries
#     LD = [dict(zip(DL,t)) for t in zip(*DL.values())]
    pickle.dump( data, open(pickle_loc +key+"_all-transcription-data-ica.p", "wb" ) )

    # Generate subtitles for the associated .MP4 video.
#     write_subtitles(out["response"], wfn = subtitle_loc + key + ".srt")
# Out:
# Sleeping 50 seconds. Started sleeping at 2018-09-24 19:57:20.865536
# Sleeping 50 seconds. Started sleeping at 2018-09-24 19:58:57.938776
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:00:09.093969
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:01:02.175163
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:02:02.145161
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:02:55.171030
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:03:58.148949
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:04:57.948956
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:05:50.519916
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:06:50.147128
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:07:42.057669
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:08:41.978810
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:09:34.158080
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:10:34.102139
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:11:36.374185
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:12:27.949549
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:13:28.404105
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:14:20.540490
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:15:21.395138
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:16:12.949656
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:17:13.110959
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:18:05.639522
# Sleeping 50 seconds. Started sleeping at 2018-09-24 20:19:06.953688
# POST requests completed. Now we fetch results via GET requests (once Google Speech API completes).
#
# Fetching. Job name: 6103817783995075916 Key: day_1__con_1__part1_source_1
# Success. Transcription received.
# Fetching. Job name: 5654488114794460514 Key: day_1__con_1__part1_source_2
# Success. Transcription received.
# Fetching. Job name: 4584068397682551433 Key: day_1__con_1__part1_source_3
# Success. Transcription received.
# Fetching. Job name: 8368889700465839542 Key: day_1__con_1__part2_source_1
# Success. Transcription received.
# Fetching. Job name: 4388217023179294519 Key: day_1__con_1__part2_source_2
# Success. Transcription received.
# Fetching. Job name: 8616878448445316717 Key: day_1__con_1__part2_source_3
# Success. Transcription received.
# Fetching. Job name: 5132371328946574195 Key: day_1__con_1__part3_source_1
# Success. Transcription received.
# Fetching. Job name: 3529589690795410648 Key: day_1__con_1__part3_source_2
# Success. Transcription received.
# Fetching. Job name: 1604547062734885325 Key: day_1__con_1__part3_source_3
# Success. Transcription received.
# Fetching. Job name: 6828698483253060567 Key: day_1__con_1__part4_source_1
# Success. Transcription received.
# Fetching. Job name: 4219717487969775234 Key: day_1__con_1__part4_source_2
# Success. Transcription received.
# Fetching. Job name: 439419264787353637 Key: day_1__con_1__part4_source_3
# Success. Transcription received.
# Fetching. Job name: 664512398087325455 Key: day_1__con_1__part5_source_1
# Success. Transcription received.
# Fetching. Job name: 5365705442324565795 Key: day_1__con_1__part5_source_2
# Success. Transcription received.
# Fetching. Job name: 3627604965584722237 Key: day_1__con_1__part5_source_3
# Success. Transcription received.
# Fetching. Job name: 5100036799626012930 Key: day_1__con_2__part1_source_1
# Success. Transcription received.
# Fetching. Job name: 856233717345220133 Key: day_1__con_2__part1_source_2
# Success. Transcription received.
# Fetching. Job name: 6445216201268756299 Key: day_1__con_2__part1_source_3
# Success. Transcription received.
# Fetching. Job name: 5696002480153589791 Key: day_1__con_2__part2_source_1
# Success. Transcription received.
# Fetching. Job name: 2340879223692264964 Key: day_1__con_2__part2_source_2
# Success. Transcription received.
# Fetching. Job name: 305577116120234474 Key: day_1__con_2__part2_source_3
# Success. Transcription received.
# Fetching. Job name: 405494493309785864 Key: day_1__con_2__part3_source_1
# Success. Transcription received.
# Fetching. Job name: 2789603133532686770 Key: day_1__con_2__part3_source_2
# Success. Transcription received.
# Fetching. Job name: 692638909336155617 Key: day_1__con_2__part3_source_3
# Success. Transcription received.
# Fetching. Job name: 2822390476332528331 Key: day_1__con_2__part4_source_1
# Success. Transcription received.
# Fetching. Job name: 245577111387036095 Key: day_1__con_2__part4_source_2
# Success. Transcription received.
# Fetching. Job name: 1399245784055215453 Key: day_1__con_2__part4_source_3
# Success. Transcription received.
# Fetching. Job name: 8218172650138816804 Key: day_1__con_2__part5_source_1
# Success. Transcription received.
# Fetching. Job name: 7123377257143987747 Key: day_1__con_2__part5_source_2
# Success. Transcription received.
# Fetching. Job name: 1098277625964939759 Key: day_1__con_2__part5_source_3
# Success. Transcription received.
# Fetching. Job name: 7399866927931238493 Key: day_1__con_3__part1_source_1
# Success. Transcription received.
# Fetching. Job name: 4446280397235195418 Key: day_1__con_3__part1_source_2
# Success. Transcription received.
# Fetching. Job name: 3956067147256784597 Key: day_1__con_3__part1_source_3
# Success. Transcription received.
# Fetching. Job name: 5654488114794459796 Key: day_1__con_3__part2_source_1
# Success. Transcription received.
# Fetching. Job name: 4826889198042138024 Key: day_1__con_3__part2_source_2
# Success. Transcription received.
# Fetching. Job name: 1608878170433435392 Key: day_1__con_3__part2_source_3
# Success. Transcription received.
# Fetching. Job name: 2747525244923398342 Key: day_1__con_3__part3_source_1
# Success. Transcription received.
# Fetching. Job name: 8569230927040748104 Key: day_1__con_3__part3_source_2
# Success. Transcription received.
# Fetching. Job name: 1558373766031159079 Key: day_1__con_3__part3_source_3
# Success. Transcription received.
# Fetching. Job name: 1202727549879435120 Key: day_1__con_3__part4_source_1
# Success. Transcription received.
# Fetching. Job name: 8885446818621373175 Key: day_1__con_3__part4_source_2
# Success. Transcription received.
# Fetching. Job name: 3703191834596618023 Key: day_1__con_3__part4_source_3
# Success. Transcription received.
# Fetching. Job name: 4818990542261335522 Key: day_1__con_4__part1_source_1
# Success. Transcription received.
# Fetching. Job name: 4890478021380425462 Key: day_1__con_4__part1_source_2
# Success. Transcription received.
# Fetching. Job name: 2051815235765080642 Key: day_1__con_4__part1_source_3
# Success. Transcription received.
# Fetching. Job name: 6094384964466823299 Key: day_1__con_4__part2_source_1
# Success. Transcription received.
# Fetching. Job name: 4784676897447679867 Key: day_1__con_4__part2_source_2
# Success. Transcription received.
# Fetching. Job name: 791576629797805538 Key: day_1__con_4__part2_source_3
# Success. Transcription received.
# Fetching. Job name: 7151634319861667549 Key: day_1__con_4__part3_source_1
# Success. Transcription received.
# Fetching. Job name: 7181831815132264902 Key: day_1__con_4__part3_source_2
# Success. Transcription received.
# Fetching. Job name: 4584068397682550163 Key: day_1__con_4__part3_source_3
# Success. Transcription received.
# Fetching. Job name: 3691671208783098856 Key: day_1__con_4__part4_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 220698417512183983 Key: day_1__con_4__part4_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 3555175760402306785 Key: day_1__con_4__part4_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 5802305908288909345 Key: day_1__con_5__part1_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 7870495003725067916 Key: day_1__con_5__part1_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 4219717487969775372 Key: day_1__con_5__part1_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 2649997985599007566 Key: day_1__con_5__part2_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 6394489485465018554 Key: day_1__con_5__part2_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 1394868143270568726 Key: day_1__con_5__part2_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 1038193943224677602 Key: day_1__con_5__part3_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 5919682616174662746 Key: day_1__con_5__part3_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 7246891574820472475 Key: day_1__con_5__part3_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 2484676062550729833 Key: day_1__con_5__part4_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 433409511728532717 Key: day_1__con_5__part4_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 1439591119734326840 Key: day_1__con_5__part4_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 7411942464143206153 Key: day_1__con_5__part5_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 2128209851207730070 Key: day_1__con_5__part5_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 3849223778467361157 Key: day_1__con_5__part5_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 6251734045221337379 Key: day_2__con_1__part1_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 8425351874233530412 Key: day_2__con_1__part1_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 6698235678140251967 Key: day_2__con_1__part1_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 4809725501086848702 Key: day_2__con_1__part2_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 646435011138460613 Key: day_2__con_1__part2_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 1242392901642207171 Key: day_2__con_1__part2_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 4687526405435643095 Key: day_2__con_1__part3_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 3471194623051090491 Key: day_2__con_1__part3_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 4890478021380425500 Key: day_2__con_1__part3_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 9092878302554317196 Key: day_2__con_1__part4_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 3414890215927537685 Key: day_2__con_1__part4_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 6652580198883278059 Key: day_2__con_1__part4_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 7507262350940878003 Key: day_2__con_1__part5_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 5399912764599603076 Key: day_2__con_1__part5_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 6772263700657762767 Key: day_2__con_1__part5_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 3588692938005923700 Key: day_2__con_2__part1_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 8434642212340622856 Key: day_2__con_2__part1_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 8485610517660143427 Key: day_2__con_2__part1_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 3176827942135453778 Key: day_2__con_2__part2_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 1439446690390897501 Key: day_2__con_2__part2_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 1343191577240009259 Key: day_2__con_2__part2_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 6609876134360771095 Key: day_2__con_2__part3_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 5828679177054154670 Key: day_2__con_2__part3_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 6484051099118935435 Key: day_2__con_2__part3_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 2996727245582485345 Key: day_2__con_2__part4_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 4532483803218379231 Key: day_2__con_2__part4_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 998022514355704493 Key: day_2__con_2__part4_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 4394983065698611219 Key: day_2__con_3_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 5164422701109066456 Key: day_2__con_3_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 5916193590038693727 Key: day_2__con_3_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 3414890215927539847 Key: day_2__con_4_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 2909123838310549596 Key: day_2__con_4_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 1354192926728553932 Key: day_2__con_4_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 4348885232693669598 Key: day_2__con_5_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 8434642212340622462 Key: day_2__con_5_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 8463170193648931682 Key: day_2__con_5_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 5685439844493883534 Key: day_2__con_6_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 8819285062261989539 Key: day_2__con_6_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 9140557841722874609 Key: day_2__con_6_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 3835627126607111188 Key: day_2__con_7_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 4936274325871289722 Key: day_2__con_7_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 3711288433826530604 Key: day_2__con_7_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 3507906809698204114 Key: day_3__con_1_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 3849223778467361217 Key: day_3__con_1_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 2551952492686350309 Key: day_3__con_1_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 7846823784323337397 Key: day_3__con_2_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 4514565210496495579 Key: day_3__con_2_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 4687526405435642981 Key: day_3__con_2_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 269919410751073626 Key: day_3__con_3_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 405494493309786843 Key: day_3__con_3_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 16116586962849835 Key: day_3__con_3_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 6502002953461038057 Key: day_3__con_4_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 1377939892974040169 Key: day_3__con_4_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 2649997985599007528 Key: day_3__con_4_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 3517015799744531686 Key: day_3__con_5_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 1051167633631284376 Key: day_3__con_5_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 6327375913834011664 Key: day_3__con_5_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 2982883913781791233 Key: day_3__con_6_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 5252472316472565807 Key: day_3__con_6_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 6640680608814995076 Key: day_3__con_6_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 1614052529103004370 Key: day_4__con_1_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 6251961636626676309 Key: day_4__con_1_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 5854867461408793600 Key: day_4__con_1_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 7536561722603258690 Key: day_4__con_2_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 3179173371657873227 Key: day_4__con_2_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 5386470645660016025 Key: day_4__con_2_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 5537341999691468079 Key: day_4__con_3_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 8390631157814421242 Key: day_4__con_3_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 522021525032465110 Key: day_4__con_3_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 1098277625964939243 Key: day_4__con_4_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 3756145432111461386 Key: day_4__con_4_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 207039882669603609 Key: day_4__con_4_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 405494493309784765 Key: day_4__con_5_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 4927704375409061630 Key: day_4__con_5_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 4917096123913236926 Key: day_4__con_5_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 2555241553352559028 Key: day_4__con_6_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 6394489485465021224 Key: day_4__con_6_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 6698235678140251033 Key: day_4__con_6_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 26196665758472035 Key: day_5__con_1_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 4309234440064237021 Key: day_5__con_1_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 7086691469309466589 Key: day_5__con_1_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 4381431824849598007 Key: day_5__con_2_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 4384694124874721310 Key: day_5__con_2_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 2669464448472800642 Key: day_5__con_2_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 191027376910789212 Key: day_5__con_3_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 5385219974278495918 Key: day_5__con_3_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 5668207791494318103 Key: day_5__con_3_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 2001287568477546467 Key: day_5__con_4_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 5847372024117148031 Key: day_5__con_4_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 6828698483253062843 Key: day_5__con_4_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 8471748423342393101 Key: day_5__con_5_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 5399922642666202661 Key: day_5__con_5_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 4698733158435690099 Key: day_5__con_5_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 2894151157247659337 Key: day_5__con_6_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 7670389388182325460 Key: day_5__con_6_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 1858114178482276561 Key: day_5__con_6_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 9006764197605548116 Key: day_5__con_7_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 1394868143270568188 Key: day_5__con_7_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 4309234440064235139 Key: day_5__con_7_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 614026196418406030 Key: day_5__con_8_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 640795052744305734 Key: day_5__con_8_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 4970941754734125863 Key: day_5__con_8_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 6125373238960048544 Key: day_6__con_1_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 8360255141543826096 Key: day_6__con_1_source_2_gs
# Still transcribing... Percent done: 85
# Still transcribing... Percent done: 85
# Success. Transcription received.
# Fetching. Job name: 4111626226252538935 Key: day_6__con_1_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 7792537392271724610 Key: day_6__con_2_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 6542885260869042484 Key: day_6__con_2_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 7184466162634222124 Key: day_6__con_2_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 1844170425024522707 Key: day_6__con_3_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 8849619217848847442 Key: day_6__con_3_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 6083081869433707682 Key: day_6__con_3_source_3_gs
# Still transcribing... Percent done: 69
# Still transcribing... Percent done: 69
# Still transcribing... Percent done: 87
# Still transcribing... Percent done: 87
# Success. Transcription received.
# Fetching. Job name: 5995065731403749593 Key: day_6__con_4_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 1944499971800804756 Key: day_6__con_4_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 1738743557174856876 Key: day_6__con_4_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 5261812035794064633 Key: day_6__con_5_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 2068419806641328884 Key: day_6__con_5_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 4973928470742358121 Key: day_6__con_5_source_3_gs
# Success. Transcription received.
# Fetching. Job name: 631874372457285874 Key: day_6__con_6_source_1_gs
# Success. Transcription received.
# Fetching. Job name: 4388217023179293953 Key: day_6__con_6_source_2_gs
# Success. Transcription received.
# Fetching. Job name: 3988643925443999702 Key: day_6__con_6_source_3_gs
# Success. Transcription received.

# %% [markdown]
# ## DEPRECATED BELOW HERE - Non-synchronous method requires the jobs to wait one at a time in Python

# %%
# Imports the Google Cloud client library
# from google.cloud import speech
# from google.cloud.speech import enums
# from google.cloud.speech import types

# Instantiates a client
# client = speech.SpeechClient()

# def transcribe_gcs(gcs_uri, verbose = False):
#     """Asynchronously transcribes the audio file specified by the gcs_uri."""
#     from google.cloud import speech
#     from google.cloud.speech import enums
#     from google.cloud.speech import types
#     client = speech.SpeechClient()

#     audio = types.RecognitionAudio(uri=gcs_uri)
#     config = types.RecognitionConfig(
#         sample_rate_hertz=44100,
#         language_code='en-US',
#         enable_word_time_offsets=True)

#     operation = client.long_running_recognize(config, audio)

#     print('Waiting for operation to complete...')
#     response = operation.result(timeout=90)

#     # Each result is for a consecutive portion of the audio. Iterate through
#     # them to get the transcripts for the entire audio file.
#     for result in response.results:
#         # The first alternative is the most likely one for this portion.
#         print(u'Transcript: {}'.format(result.alternatives[0].transcript))
#         print('Confidence: {}'.format(result.alternatives[0].confidence))
        
#     return response


# def srt_format_timestamp(seconds):
#     stamp = str(timedelta(seconds=seconds))
#     first, second, third = stamp.split(":")
#     third = "{:.3f}".format(float(third))
#     sec, milisec = third.split(".")
#     third = ",".join([sec.zfill(2), milisec])
#     return ":".join([first.zfill(2), second.zfill(2), third])



# # The name of the audio file to transcribe
# file_name = "/home/cgn/Downloads/egocom-audio-only-summed/day_1__con_1__part1.wav"

# # Loads the audio into memory
# with io.open(file_name, 'rb') as audio_file:
#     content = audio_file.read()
#     audio = types.RecognitionAudio(content=content)

# config = types.RecognitionConfig(
#     encoding=enums.RecognitionConfig.AudioEncoding.LINEAR16,
#     sample_rate_hertz=16000,
#     language_code='en-US')

# # Detects speech in the audio file
# response = client.recognize(config, audio)

# for result in response.results:
#     print('Transcript: {}'.format(result.alternatives[0].transcript))
    
# result = transcribe_gcs("gs://egocom-audio/wav16-summed/day_1__con_1__part1.wav")


# max_words_per_subtitle = 16
# wfn = "/home/cgn/Downloads/egocom-aligned/out.srt"
# wf = open(wfn, 'a') if wfn is not None else wfn

# cnt = 0
# for r in result.results:
#     alternative = r.alternatives[0]
#     for i in range(0, len(alternative.words), max_words_per_subtitle):
#         cnt += 1
#         words_range = alternative.words[i:i+max_words_per_subtitle]
#         words = [word_info.word for word_info in words_range]
#         words = " ".join(words[:len(words) // 2]) +  "\n" + " ".join(words[len(words) // 2:])
#         start_time = words_range[0].start_time.seconds + words_range[0].start_time.nanos * 1e-9
#         end_time =  words_range[-1].end_time.seconds + words_range[-1].end_time.nanos * 1e-9
#         print(cnt, file=wf)
#         print(srt_format_timestamp(start_time), "-->", srt_format_timestamp(end_time), file=wf)
#         print(words, file=wf)
#         print(file=wf)
